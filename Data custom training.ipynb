# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# D:\KhoaLuanTotNghiep

# %%
from IPython import display
display.clear_output()
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.24  Python-3.10.0 torch-2.2.0+cpu CPU (Intel Core(TM) i7-10870H 2.20GHz)
# Setup complete  (16 CPUs, 31.8 GB RAM, 16.8/55.8 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image, clear_output

# %%
# %cd dataset

from roboflow import Roboflow
rf = Roboflow(api_key="U2oGbdr5oOooHKrjNdpu")
project = rf.workspace("trainingcustomobject").project("customtraining-r9tf2")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# D:\KhoaLuanTotNghiep\dataset
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.24, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Custom-Vehicle-version-2-1 in yolov8:: 100%|█████| 318/318 [00:00<00:00, 2286.31it/s]

# %%
# %cd ..
# Out:
# D:\KhoaLuanTotNghiep

# %%
# !yolo task=detect mode=train model=yolov8s.pt data={HOME}/dataset/Custom-Vehicle-version-2-1/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.2.35 available ðŸ˜ƒ Update with 'pip install -U ultralytics'
# train: Scanning D:\KhoaLuanTotNghiep\dataset\Custom-Vehicle-version-2-1\train\labels...:   0%|          | 0/123 [00:00<?, ?it/s]
# train: Scanning D:\KhoaLuanTotNghiep\dataset\Custom-Vehicle-version-2-1\train\labels... 49 images, 0 backgrounds, 0 corrupt:  40%|###9      | 49/123 [00:00<00:00, 459.32it/s]
# train: Scanning D:\KhoaLuanTotNghiep\dataset\Custom-Vehicle-version-2-1\train\labels... 123 images, 2 backgrounds, 0 corrupt: 100%|##########| 123/123 [00:00<00:00, 607.60it/s]
#
# val: Scanning D:\KhoaLuanTotNghiep\dataset\Custom-Vehicle-version-2-1\valid\labels...:   0%|          | 0/20 [00:00<?, ?it/s]
# val: Scanning D:\KhoaLuanTotNghiep\dataset\Custom-Vehicle-version-2-1\valid\labels... 20 images, 1 backgrounds, 0 corrupt: 100%|##########| 20/20 [00:00<00:00, 560.45it/s]
#
#   0%|          | 0/8 [00:00<?, ?it/s]
# ...

# %%
Image(filename=f'{HOME}/runs/detect/train3/confusion_matrix.png', width=600)

# %%
Image(filename=f'{HOME}/runs/detect/train3/results.png', width=600)

# %%
Image(filename=f'{HOME}/runs/detect/train3/val_batch0_pred.jpg', width=600)

# %%
 # !yolo task=detect mode=predict model={HOME}/runs/detect/train3/weights/best.pt conf=0.25 source=f'{HOME}/Vehicle2.mp4' save=True
# Out:
# ^C
